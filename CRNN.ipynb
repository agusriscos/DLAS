# %%
# Code to read csv file into Colaboratory:
# !pip install -U -q PyDrive
from pydrive.auth import GoogleAuth
from pydrive.drive import GoogleDrive
from google.colab import auth
from oauth2client.client import GoogleCredentials
# Authenticate and create the PyDrive client.
auth.authenticate_user()
gauth = GoogleAuth()
gauth.credentials = GoogleCredentials.get_application_default()
drive = GoogleDrive(gauth)

# %%
import pandas as pd
link = 'https://drive.google.com/open?id=1xT20kiC6bhWPps_uuB_5Jty5I_LbDevc'
id = link.split("=")[1]

downloaded = drive.CreateFile({'id':id}) 
downloaded.GetContentFile('pre_processing.csv')  
featuresdf = pd.read_csv('pre_processing.csv')
# Dataset is now stored in a Pandas Dataframe

# %%
import numpy as np
from sklearn.preprocessing import LabelEncoder
from keras.utils import to_categorical
from sklearn.model_selection import train_test_split
from sklearn.model_selection import StratifiedKFold

# Convert features and corresponding classification labels into numpy arrays
X = featuresdf.loc[:,['feature_0', 'feature_1', 'feature_2', 'feature_3', 'feature_4', 'feature_5', 'feature_6', 'feature_7', 'feature_8', 'feature_9',
                     'feature_10', 'feature_11', 'feature_12', 'feature_13', 'feature_14', 'feature_15', 'feature_16', 'feature_17', 'feature_18',
                     'feature_19', 'feature_20', 'feature_21', 'feature_22', 'feature_23', 'feature_24', 'feature_25', 'feature_26', 'feature_27',
                     'feature_28', 'feature_29', 'feature_30', 'feature_31', 'feature_32', 'feature_33', 'feature_34', 'feature_35', 'feature_36',
                     'feature_37', 'feature_38', 'feature_39']].values
X = np.array(X)
y = np.array(featuresdf.label.tolist())
print(y)
# Encode the classification labels
le = LabelEncoder()
yy = to_categorical(le.fit_transform(y))
print(yy)
# split the dataset 
x_train, x_test, y_train, y_test = train_test_split(X, yy, test_size=0.2)
# Out:
# Using TensorFlow backend.
# ['keyboard' 'keyboard' 'keyboard' ... 'silence' 'silence' 'keyboard']
# [[0. 1. 0.]
#  [0. 1. 0.]
#  [0. 1. 0.]
#  ...
#  [0. 0. 1.]
#  [0. 0. 1.]
#  [0. 1. 0.]]

# %%
yDf = pd.DataFrame({'label': y})
yDf["label"].value_counts()
# Out:
# silence         2000
# conversation    2000
# keyboard        1966
# Name: label, dtype: int64

# %%
X[0].shape
# Out:
# (40,)

# %% [markdown]
# ### Initial model architecture - MLP
#
# We will start with constructing a Multilayer Perceptron (MLP) Neural Network using Keras and a Tensorflow backend.
#
# Starting with a `sequential` model so we can build the model layer by layer.
#
# We will begin with a simple model architecture, consisting of three layers, an input layer, a hidden layer and an output layer. All three layers will be of the `dense` layer type which is a standard layer type that is used in many cases for neural networks.
#
# The first layer will receive the input shape. As each sample contains 40 MFCCs (or columns) we have a shape of (1x40) this means we will start with an input shape of 40.
#
# The first two layers will have 256 nodes. The activation function we will be using for our first 2 layers is the `ReLU`, or `Rectified Linear Activation`. This activation function has been proven to work well in neural networks.
#
# We will also apply a `Dropout` value of 50% on our first two layers. This will randomly exclude nodes from each update cycle which in turn results in a network that is capable of better generalisation and is less likely to overfit the training data.
#
# Our output layer will have 10 nodes (num_labels) which matches the number of possible classifications. The activation is for our output layer is `softmax`. Softmax makes the output sum up to 1 so the output can be interpreted as probabilities. The model will then make its prediction based on which option has the highest probability.

# %% [markdown]
# #### Métricas personalizadas: especificidad, sensibilidad y f1 score

# %%
def recall_m(y_true, y_pred):
        true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
        possible_positives = K.sum(K.round(K.clip(y_true, 0, 1)))
        recall = true_positives / (possible_positives + K.epsilon())
        return recall

def precision_m(y_true, y_pred):
        true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
        predicted_positives = K.sum(K.round(K.clip(y_pred, 0, 1)))
        precision = true_positives / (predicted_positives + K.epsilon())
        return precision

def f1_m(y_true, y_pred):
    precision = precision_m(y_true, y_pred)
    recall = recall_m(y_true, y_pred)
    return 2*((precision*recall)/(precision+recall+K.epsilon()))

# %%
import keras
from keras import optimizers
from keras import backend as K
from keras import regularizers
from keras.models import Sequential
from keras.layers import Dense, Activation, Dropout, Flatten, Bidirectional
from keras.layers import Conv1D, MaxPooling1D, GlobalMaxPooling1D, LSTM, GRU

num_labels = yy.shape[1]
filter_size = 2


model = Sequential()
model.add(Conv1D(64, 3, activation='relu', input_shape=(40,1)))
model.add(MaxPooling1D(pool_size=4))
model.add(Bidirectional(GRU(128)))
model.add(Dropout(0.5)) # **** considerar
model.add(Dense(num_labels))
model.add(Activation('softmax'))
    
model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy', f1_m, precision_m, recall_m])

model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d_1 (Conv1D)            (None, 38, 64)            256
# _________________________________________________________________
# max_pooling1d_1 (MaxPooling1 (None, 9, 64)             0
# _________________________________________________________________
# bidirectional_1 (Bidirection (None, 256)               148224
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 3)                 771
# _________________________________________________________________
# activation_1 (Activation)    (None, 3)                 0
# =================================================================
# Total params: 149,251
# Trainable params: 149,251
# Non-trainable params: 0
# _________________________________________________________________

# %%
import os
if not os.path.exists('./saved_models'):
    os.makedirs('saved_models')

# %%
x_train.shape
# Out:
# (4772, 40)

# %%
x_train_reshaped = x_train.reshape(4772,40,1)
x_train_reshaped.shape
# Out:
# (4772, 40, 1)

# %%
from keras.callbacks import ModelCheckpoint, EarlyStopping
import time

num_epochs = 100
num_batch_size = 32

checkpointer = ModelCheckpoint(filepath='saved_models/weights.best.basic_mlp.hdf5', 
                               verbose=1, save_best_only=True)
early_stopper = EarlyStopping(monitor='val_loss', patience=20)

start = time.time()
hist = model.fit(x_train_reshaped, y_train, batch_size=num_batch_size, epochs=num_epochs, validation_split=0.2, callbacks=[checkpointer, early_stopper], verbose=1)
duration = time.time() - start
print("Training completed in time (s): ", duration)
# Out:
# Train on 3817 samples, validate on 955 samples
# Epoch 1/100
# 3817/3817 [==============================] - 13s 3ms/step - loss: 0.1974 - accuracy: 0.9201 - f1_m: 0.9188 - precision_m: 0.9250 - recall_m: 0.9135 - val_loss: 0.0606 - val_accuracy: 0.9759 - val_f1_m: 0.9763 - val_precision_m: 0.9769 - val_recall_m: 0.9758
#
# Epoch 00001: val_loss improved from inf to 0.06060, saving model to saved_models/weights.best.basic_mlp.hdf5
# Epoch 2/100
# 3817/3817 [==============================] - 6s 2ms/step - loss: 0.0439 - accuracy: 0.9851 - f1_m: 0.9851 - precision_m: 0.9859 - recall_m: 0.9844 - val_loss: 0.0331 - val_accuracy: 0.9937 - val_f1_m: 0.9937 - val_precision_m: 0.9937 - val_recall_m: 0.9937
#
# Epoch 00002: val_loss improved from 0.06060 to 0.03313, saving model to saved_models/weights.best.basic_mlp.hdf5
# Epoch 3/100
# 3817/3817 [==============================] - 6s 2ms/step - loss: 0.0307 - accuracy: 0.9903 - f1_m: 0.9906 - precision_m: 0.9911 - recall_m: 0.9901 - val_loss: 0.0452 - val_accuracy: 0.9864 - val_f1_m: 0.9857 - val_precision_m: 0.9863 - val_recall_m: 0.9852
#
# Epoch 00003: val_loss did not improve from 0.03313
# Epoch 4/100
# 3817/3817 [==============================] - 6s 2ms/step - loss: 0.0302 - accuracy: 0.9890 - f1_m: 0.9892 - precision_m: 0.9893 - recall_m: 0.9891 - val_loss: 0.0589 - val_accuracy: 0.9801 - val_f1_m: 0.9802 - val_precision_m: 0.9802 - val_recall_m: 0.9802
#
# Epoch 00004: val_loss did not improve from 0.03313
# Epoch 5/100
# 3817/3817 [==============================] - 6s 2ms/step - loss: 0.0224 - accuracy: 0.9935 - f1_m: 0.9935 - precision_m: 0.9940 - recall_m: 0.9930 - val_loss: 0.1503 - val_accuracy: 0.9361 - val_f1_m: 0.9364 - val_precision_m: 0.9369 - val_recall_m: 0.9359
#
# Epoch 00005: val_loss did not improve from 0.03313
# Epoch 6/100
# 3817/3817 [==============================] - 6s 2ms/step - loss: 0.0294 - accuracy: 0.9903 - f1_m: 0.9901 - precision_m: 0.9904 - recall_m: 0.9898 - val_loss: 0.0229 - val_accuracy: 0.9937 - val_f1_m: 0.9937 - val_precision_m: 0.9937 - val_recall_m: 0.9937
#
# Epoch 00006: val_loss improved from 0.03313 to 0.02294, saving model to saved_models/weights.best.basic_mlp.hdf5
# Epoch 7/100
# 3817/3817 [==============================] - 6s 2ms/step - loss: 0.0225 - accuracy: 0.9935 - f1_m: 0.9935 - precision_m: 0.9935 - recall_m: 0.9935 - val_loss: 0.0400 - val_accuracy: 0.9895 - val_f1_m: 0.9894 - val_precision_m: 0.9894 - val_recall_m: 0.9894
#
# Epoch 00007: val_loss did not improve from 0.02294
# Epoch 8/100
# 3817/3817 [==============================] - 6s 2ms/step - loss: 0.0132 - accuracy: 0.9955 - f1_m: 0.9956 - precision_m: 0.9958 - recall_m: 0.9953 - val_loss: 0.0774 - val_accuracy: 0.9812 - val_f1_m: 0.9811 - val_precision_m: 0.9811 - val_recall_m: 0.9811
#
# Epoch 00008: val_loss did not improve from 0.02294
# Epoch 9/100
# 3817/3817 [==============================] - 6s 2ms/step - loss: 0.0213 - accuracy: 0.9935 - f1_m: 0.9936 - precision_m: 0.9937 - recall_m: 0.9935 - val_loss: 0.0296 - val_accuracy: 0.9916 - val_f1_m: 0.9917 - val_precision_m: 0.9917 - val_recall_m: 0.9917
#
# Epoch 00009: val_loss did not improve from 0.02294
# Epoch 10/100
# 3817/3817 [==============================] - 6s 2ms/step - loss: 0.0136 - accuracy: 0.9950 - f1_m: 0.9951 - precision_m: 0.9951 - recall_m: 0.9951 - val_loss: 0.0241 - val_accuracy: 0.9937 - val_f1_m: 0.9937 - val_precision_m: 0.9937 - val_recall_m: 0.9937
#
# Epoch 00010: val_loss did not improve from 0.02294
# Epoch 11/100
# 3817/3817 [==============================] - 6s 2ms/step - loss: 0.0127 - accuracy: 0.9958 - f1_m: 0.9958 - precision_m: 0.9958 - recall_m: 0.9958 - val_loss: 0.0460 - val_accuracy: 0.9885 - val_f1_m: 0.9885 - val_precision_m: 0.9885 - val_recall_m: 0.9885
#
# Epoch 00011: val_loss did not improve from 0.02294
# Epoch 12/100
# 3817/3817 [==============================] - 6s 2ms/step - loss: 0.0133 - accuracy: 0.9948 - f1_m: 0.9948 - precision_m: 0.9948 - recall_m: 0.9948 - val_loss: 0.0270 - val_accuracy: 0.9916 - val_f1_m: 0.9917 - val_precision_m: 0.9917 - val_recall_m: 0.9917
#
# Epoch 00012: val_loss did not improve from 0.02294
# Epoch 13/100
# 3817/3817 [==============================] - 6s 2ms/step - loss: 0.0133 - accuracy: 0.9958 - f1_m: 0.9960 - precision_m: 0.9961 - recall_m: 0.9958 - val_loss: 0.0226 - val_accuracy: 0.9906 - val_f1_m: 0.9911 - val_precision_m: 0.9917 - val_recall_m: 0.9906
#
# Epoch 00013: val_loss improved from 0.02294 to 0.02262, saving model to saved_models/weights.best.basic_mlp.hdf5
# Epoch 14/100
# 3817/3817 [==============================] - 6s 2ms/step - loss: 0.0126 - accuracy: 0.9950 - f1_m: 0.9951 - precision_m: 0.9951 - recall_m: 0.9951 - val_loss: 0.0280 - val_accuracy: 0.9927 - val_f1_m: 0.9927 - val_precision_m: 0.9927 - val_recall_m: 0.9927
#
# Epoch 00014: val_loss did not improve from 0.02262
# Epoch 15/100
# 3817/3817 [==============================] - 6s 2ms/step - loss: 0.0044 - accuracy: 0.9990 - f1_m: 0.9988 - precision_m: 0.9990 - recall_m: 0.9987 - val_loss: 0.0252 - val_accuracy: 0.9927 - val_f1_m: 0.9927 - val_precision_m: 0.9927 - val_recall_m: 0.9927
#
# Epoch 00015: val_loss did not improve from 0.02262
# Epoch 16/100
# 3817/3817 [==============================] - 6s 2ms/step - loss: 0.0057 - accuracy: 0.9987 - f1_m: 0.9987 - precision_m: 0.9987 - recall_m: 0.9987 - val_loss: 0.0271 - val_accuracy: 0.9937 - val_f1_m: 0.9937 - val_precision_m: 0.9937 - val_recall_m: 0.9937
#
# Epoch 00016: val_loss did not improve from 0.02262
# Epoch 17/100
# 3817/3817 [==============================] - 6s 2ms/step - loss: 0.0084 - accuracy: 0.9971 - f1_m: 0.9973 - precision_m: 0.9974 - recall_m: 0.9971 - val_loss: 0.0212 - val_accuracy: 0.9958 - val_f1_m: 0.9958 - val_precision_m: 0.9958 - val_recall_m: 0.9958
#
# Epoch 00017: val_loss improved from 0.02262 to 0.02117, saving model to saved_models/weights.best.basic_mlp.hdf5
# Epoch 18/100
# 3817/3817 [==============================] - 6s 2ms/step - loss: 0.0105 - accuracy: 0.9974 - f1_m: 0.9975 - precision_m: 0.9976 - recall_m: 0.9974 - val_loss: 0.0272 - val_accuracy: 0.9937 - val_f1_m: 0.9937 - val_precision_m: 0.9937 - val_recall_m: 0.9937
#
# Epoch 00018: val_loss did not improve from 0.02117
# Epoch 19/100
# 3817/3817 [==============================] - 6s 2ms/step - loss: 0.0039 - accuracy: 0.9987 - f1_m: 0.9987 - precision_m: 0.9987 - recall_m: 0.9987 - val_loss: 0.0209 - val_accuracy: 0.9937 - val_f1_m: 0.9937 - val_precision_m: 0.9937 - val_recall_m: 0.9937
#
# Epoch 00019: val_loss improved from 0.02117 to 0.02086, saving model to saved_models/weights.best.basic_mlp.hdf5
# Epoch 20/100
# 3817/3817 [==============================] - 6s 2ms/step - loss: 0.0167 - accuracy: 0.9950 - f1_m: 0.9951 - precision_m: 0.9951 - recall_m: 0.9951 - val_loss: 0.0891 - val_accuracy: 0.9759 - val_f1_m: 0.9760 - val_precision_m: 0.9760 - val_recall_m: 0.9760
#
# Epoch 00020: val_loss did not improve from 0.02086
# Epoch 21/100
# 3817/3817 [==============================] - 6s 2ms/step - loss: 0.0176 - accuracy: 0.9942 - f1_m: 0.9941 - precision_m: 0.9943 - recall_m: 0.9940 - val_loss: 0.0195 - val_accuracy: 0.9948 - val_f1_m: 0.9948 - val_precision_m: 0.9948 - val_recall_m: 0.9948
#
# Epoch 00021: val_loss improved from 0.02086 to 0.01953, saving model to saved_models/weights.best.basic_mlp.hdf5
# Epoch 22/100
# 3817/3817 [==============================] - 6s 2ms/step - loss: 0.0061 - accuracy: 0.9982 - f1_m: 0.9983 - precision_m: 0.9984 - recall_m: 0.9982 - val_loss: 0.0383 - val_accuracy: 0.9927 - val_f1_m: 0.9925 - val_precision_m: 0.9925 - val_recall_m: 0.9925
#
# Epoch 00022: val_loss did not improve from 0.01953
# Epoch 23/100
# 3817/3817 [==============================] - 6s 2ms/step - loss: 0.0095 - accuracy: 0.9974 - f1_m: 0.9974 - precision_m: 0.9974 - recall_m: 0.9974 - val_loss: 0.0229 - val_accuracy: 0.9937 - val_f1_m: 0.9937 - val_precision_m: 0.9937 - val_recall_m: 0.9937
#
# Epoch 00023: val_loss did not improve from 0.01953
# Epoch 24/100
# 3817/3817 [==============================] - 6s 2ms/step - loss: 0.0098 - accuracy: 0.9963 - f1_m: 0.9964 - precision_m: 0.9964 - recall_m: 0.9964 - val_loss: 0.0237 - val_accuracy: 0.9937 - val_f1_m: 0.9937 - val_precision_m: 0.9937 - val_recall_m: 0.9937
#
# Epoch 00024: val_loss did not improve from 0.01953
# Epoch 25/100
# 3817/3817 [==============================] - 6s 2ms/step - loss: 0.0039 - accuracy: 0.9984 - f1_m: 0.9984 - precision_m: 0.9984 - recall_m: 0.9984 - val_loss: 0.0169 - val_accuracy: 0.9958 - val_f1_m: 0.9958 - val_precision_m: 0.9958 - val_recall_m: 0.9958
#
# Epoch 00025: val_loss improved from 0.01953 to 0.01689, saving model to saved_models/weights.best.basic_mlp.hdf5
# Epoch 26/100
# 3817/3817 [==============================] - 6s 2ms/step - loss: 0.0052 - accuracy: 0.9982 - f1_m: 0.9982 - precision_m: 0.9982 - recall_m: 0.9982 - val_loss: 0.0295 - val_accuracy: 0.9906 - val_f1_m: 0.9906 - val_precision_m: 0.9906 - val_recall_m: 0.9906
#
# Epoch 00026: val_loss did not improve from 0.01689
# Epoch 27/100
# 3817/3817 [==============================] - 6s 2ms/step - loss: 0.0033 - accuracy: 0.9984 - f1_m: 0.9984 - precision_m: 0.9984 - recall_m: 0.9984 - val_loss: 0.0553 - val_accuracy: 0.9874 - val_f1_m: 0.9875 - val_precision_m: 0.9875 - val_recall_m: 0.9875
#
# Epoch 00027: val_loss did not improve from 0.01689
# Epoch 28/100
# 3817/3817 [==============================] - 6s 2ms/step - loss: 0.0135 - accuracy: 0.9955 - f1_m: 0.9957 - precision_m: 0.9958 - recall_m: 0.9956 - val_loss: 0.0202 - val_accuracy: 0.9948 - val_f1_m: 0.9948 - val_precision_m: 0.9948 - val_recall_m: 0.9948
#
# Epoch 00028: val_loss did not improve from 0.01689
# Epoch 29/100
# 3817/3817 [==============================] - 6s 2ms/step - loss: 0.0047 - accuracy: 0.9984 - f1_m: 0.9978 - precision_m: 0.9978 - recall_m: 0.9978 - val_loss: 0.0326 - val_accuracy: 0.9948 - val_f1_m: 0.9948 - val_precision_m: 0.9948 - val_recall_m: 0.9948
#
# Epoch 00029: val_loss did not improve from 0.01689
# Epoch 30/100
# 3817/3817 [==============================] - 6s 2ms/step - loss: 0.0076 - accuracy: 0.9969 - f1_m: 0.9969 - precision_m: 0.9969 - recall_m: 0.9969 - val_loss: 0.0276 - val_accuracy: 0.9937 - val_f1_m: 0.9936 - val_precision_m: 0.9936 - val_recall_m: 0.9936
#
# Epoch 00030: val_loss did not improve from 0.01689
# Epoch 31/100
# 3817/3817 [==============================] - 6s 2ms/step - loss: 0.0203 - accuracy: 0.9932 - f1_m: 0.9934 - precision_m: 0.9935 - recall_m: 0.9932 - val_loss: 0.0258 - val_accuracy: 0.9927 - val_f1_m: 0.9927 - val_precision_m: 0.9927 - val_recall_m: 0.9927
#
# Epoch 00031: val_loss did not improve from 0.01689
# Epoch 32/100
# 3817/3817 [==============================] - 6s 2ms/step - loss: 0.0044 - accuracy: 0.9984 - f1_m: 0.9984 - precision_m: 0.9984 - recall_m: 0.9984 - val_loss: 0.0274 - val_accuracy: 0.9927 - val_f1_m: 0.9927 - val_precision_m: 0.9927 - val_recall_m: 0.9927
#
# Epoch 00032: val_loss did not improve from 0.01689
# Epoch 33/100
# 3817/3817 [==============================] - 6s 2ms/step - loss: 0.0041 - accuracy: 0.9987 - f1_m: 0.9988 - precision_m: 0.9990 - recall_m: 0.9987 - val_loss: 0.0176 - val_accuracy: 0.9948 - val_f1_m: 0.9948 - val_precision_m: 0.9948 - val_recall_m: 0.9948
#
# Epoch 00033: val_loss did not improve from 0.01689
# Epoch 34/100
# 3817/3817 [==============================] - 6s 2ms/step - loss: 0.0072 - accuracy: 0.9966 - f1_m: 0.9966 - precision_m: 0.9966 - recall_m: 0.9966 - val_loss: 0.0212 - val_accuracy: 0.9937 - val_f1_m: 0.9937 - val_precision_m: 0.9937 - val_recall_m: 0.9937
#
# Epoch 00034: val_loss did not improve from 0.01689
# Epoch 35/100
# 3817/3817 [==============================] - 6s 2ms/step - loss: 0.0023 - accuracy: 0.9992 - f1_m: 0.9992 - precision_m: 0.9992 - recall_m: 0.9992 - val_loss: 0.0192 - val_accuracy: 0.9958 - val_f1_m: 0.9958 - val_precision_m: 0.9958 - val_recall_m: 0.9958
#
# Epoch 00035: val_loss did not improve from 0.01689
# Epoch 36/100
# 3817/3817 [==============================] - 6s 2ms/step - loss: 9.4283e-04 - accuracy: 0.9997 - f1_m: 0.9997 - precision_m: 0.9997 - recall_m: 0.9997 - val_loss: 0.0242 - val_accuracy: 0.9958 - val_f1_m: 0.9958 - val_precision_m: 0.9958 - val_recall_m: 0.9958
#
# Epoch 00036: val_loss did not improve from 0.01689
# Epoch 37/100
# 3817/3817 [==============================] - 6s 2ms/step - loss: 2.1857e-04 - accuracy: 1.0000 - f1_m: 1.0000 - precision_m: 1.0000 - recall_m: 1.0000 - val_loss: 0.0268 - val_accuracy: 0.9937 - val_f1_m: 0.9937 - val_precision_m: 0.9937 - val_recall_m: 0.9937
#
# Epoch 00037: val_loss did not improve from 0.01689
# Epoch 38/100
# 3817/3817 [==============================] - 6s 2ms/step - loss: 2.0123e-04 - accuracy: 1.0000 - f1_m: 1.0000 - precision_m: 1.0000 - recall_m: 1.0000 - val_loss: 0.0255 - val_accuracy: 0.9958 - val_f1_m: 0.9958 - val_precision_m: 0.9958 - val_recall_m: 0.9958
#
# Epoch 00038: val_loss did not improve from 0.01689
# Epoch 39/100
# 3817/3817 [==============================] - 6s 2ms/step - loss: 1.3079e-04 - accuracy: 1.0000 - f1_m: 1.0000 - precision_m: 1.0000 - recall_m: 1.0000 - val_loss: 0.0268 - val_accuracy: 0.9958 - val_f1_m: 0.9958 - val_precision_m: 0.9958 - val_recall_m: 0.9958
#
# Epoch 00039: val_loss did not improve from 0.01689
# Epoch 40/100
# 3817/3817 [==============================] - 6s 2ms/step - loss: 2.9094e-04 - accuracy: 1.0000 - f1_m: 1.0000 - precision_m: 1.0000 - recall_m: 1.0000 - val_loss: 0.0316 - val_accuracy: 0.9937 - val_f1_m: 0.9937 - val_precision_m: 0.9937 - val_recall_m: 0.9937
#
# Epoch 00040: val_loss did not improve from 0.01689
# Epoch 41/100
# 3817/3817 [==============================] - 6s 2ms/step - loss: 2.2650e-04 - accuracy: 1.0000 - f1_m: 1.0000 - precision_m: 1.0000 - recall_m: 1.0000 - val_loss: 0.0250 - val_accuracy: 0.9948 - val_f1_m: 0.9948 - val_precision_m: 0.9948 - val_recall_m: 0.9948
#
# Epoch 00041: val_loss did not improve from 0.01689
# Epoch 42/100
# 3817/3817 [==============================] - 6s 2ms/step - loss: 1.9636e-04 - accuracy: 1.0000 - f1_m: 1.0000 - precision_m: 1.0000 - recall_m: 1.0000 - val_loss: 0.0265 - val_accuracy: 0.9948 - val_f1_m: 0.9948 - val_precision_m: 0.9948 - val_recall_m: 0.9948
#
# Epoch 00042: val_loss did not improve from 0.01689
# Epoch 43/100
# 3817/3817 [==============================] - 6s 2ms/step - loss: 6.4387e-05 - accuracy: 1.0000 - f1_m: 1.0000 - precision_m: 1.0000 - recall_m: 1.0000 - val_loss: 0.0250 - val_accuracy: 0.9948 - val_f1_m: 0.9948 - val_precision_m: 0.9948 - val_recall_m: 0.9948
#
# Epoch 00043: val_loss did not improve from 0.01689
# Epoch 44/100
# 3817/3817 [==============================] - 6s 2ms/step - loss: 4.1350e-05 - accuracy: 1.0000 - f1_m: 1.0000 - precision_m: 1.0000 - recall_m: 1.0000 - val_loss: 0.0255 - val_accuracy: 0.9948 - val_f1_m: 0.9948 - val_precision_m: 0.9948 - val_recall_m: 0.9948
#
# Epoch 00044: val_loss did not improve from 0.01689
# Epoch 45/100
# 3817/3817 [==============================] - 6s 2ms/step - loss: 8.2433e-05 - accuracy: 1.0000 - f1_m: 1.0000 - precision_m: 1.0000 - recall_m: 1.0000 - val_loss: 0.0237 - val_accuracy: 0.9958 - val_f1_m: 0.9958 - val_precision_m: 0.9958 - val_recall_m: 0.9958
#
# Epoch 00045: val_loss did not improve from 0.01689
# Training completed in time (s):  282.51027369499207

# %%
ts = time.time()
model.save("CRNN_" + str(ts).split('.')[0] + ".h5")
print("Saved model to disk")
# Out:
# Saved model to disk

# %% [markdown]
# ### Curvas de aprendizaje

# %%
import matplotlib.pyplot as plt

#generate plots
plt.figure()
plt.plot(hist.history['loss'], lw=2.0, color='b', label='train')
plt.plot(hist.history['val_loss'], lw=2.0, color='r', label='val')
plt.title('Optimization Curve')
plt.xlabel('Epochs')
plt.ylabel('Cross-Entropy Loss')
plt.legend(loc='upper right')
plt.show()

# %%
plt.figure()
plt.plot(hist.history['accuracy'], lw=2.0, color='b', label='train')
plt.plot(hist.history['val_accuracy'], lw=2.0, color='r', label='val')
plt.title('Accuracy Performance')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')

plt.legend(loc='upper left')
plt.show()

# %%
plt.figure()
plt.plot(hist.history['f1_m'], lw=2.0, color='b', label='train')
plt.plot(hist.history['val_f1_m'], lw=2.0, color='r', label='val')
plt.title('F1 Performance')
plt.xlabel('Epochs')
plt.ylabel('F1_score')

plt.legend(loc='upper left')
plt.show()

# %%
x_test_reshaped = x_test.reshape(x_test.shape[0], x_test.shape[1], 1)

# %%
loss, accuracy, f1_score, precision, recall = model.evaluate(x_test_reshaped, y_test, verbose=0)

# %%
print(loss, accuracy, f1_score, precision, recall)
# Out:
# 0.015195308254764485 0.9949748516082764 0.9950658082962036 0.9950658082962036 0.9950658082962036

# %%
from sklearn.metrics import confusion_matrix

predictions = model.predict(x_test_reshaped)
c_m = confusion_matrix(y_test.argmax(axis=1), predictions.argmax(axis=1))

# %%
print(c_m)
# Out:
# [[418   1   2]
#  [  3 383   0]
#  [  0   0 387]]

# %%
import plotly.express as px
fig = px.imshow(c_m)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="2b0cd3ba-d87e-493a-b75b-36037ead8e70" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("2b0cd3ba-d87e-493a-b75b-36037ead8e70")) {
#                     Plotly.newPlot(
#                         '2b0cd3ba-d87e-493a-b75b-36037ead8e70',
#                         [{"coloraxis": "coloraxis", "type": "heatmap", "z": [[418, 1, 2], [3, 383, 0], [0, 0, 387]]}],
#                         {"coloraxis": {"colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]]}, "margin": {"t": 60}, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2dcontour"}], "mesh3d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "mesh3d"}], "parcoords": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "parcoords"}], "pie": [{"automargin": true, "type": "pie"}], "scatter": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter"}], "scatter3d": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter3d"}], "scattercarpet": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattercarpet"}], "scattergeo": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergeo"}], "scattergl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergl"}], "scat ...

# %%
import plotly.figure_factory as ff

z = c_m

x = ['conversation', 'keyboard', 'air conditioning']
y =  ['conversation', 'keyboard', 'air conditioning']

# change each element of z to type string for annotations
z_text = [[str(y) for y in x] for x in z]

# set up figure 
fig = ff.create_annotated_heatmap(z, x=x, y=y, annotation_text=z_text, colorscale='Viridis')

# add custom xaxis title
fig.add_annotation(dict(font=dict(color="black",size=14),
                        x=0.5,
                        y=-0.15,
                        showarrow=False,
                        text="Predicted value",
                        xref="paper",
                        yref="paper"))

# add custom yaxis title
fig.add_annotation(dict(font=dict(color="black",size=14),
                        x=-0.35,
                        y=0.5,
                        showarrow=False,
                        text="Real value",
                        textangle=-90,
                        xref="paper",
                        yref="paper"))

# adjust margins to make room for yaxis title
fig.update_layout(margin=dict(t=50, l=200))

# add colorbar
fig['data'][0]['showscale'] = True
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="290d7e95-d94c-41f3-9fe6-bce5c03b2ebd" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("290d7e95-d94c-41f3-9fe6-bce5c03b2ebd")) {
#                     Plotly.newPlot(
#                         '290d7e95-d94c-41f3-9fe6-bce5c03b2ebd',
#                         [{"colorscale": [[0.0, "#440154"], [0.1111111111111111, "#482878"], [0.2222222222222222, "#3e4989"], [0.3333333333333333, "#31688e"], [0.4444444444444444, "#26828e"], [0.5555555555555556, "#1f9e89"], [0.6666666666666666, "#35b779"], [0.7777777777777778, "#6ece58"], [0.8888888888888888, "#b5de2b"], [1.0, "#fde725"]], "reversescale": false, "showscale": true, "type": "heatmap", "x": ["conversation", "keyboard", "air conditioning"], "y": ["conversation", "keyboard", "air conditioning"], "z": [[418, 1, 2], [3, 383, 0], [0, 0, 387]]}],
#                         {"annotations": [{"font": {"color": "#000000"}, "showarrow": false, "text": "418", "x": "conversation", "xref": "x", "y": "conversation", "yref": "y"}, {"font": {"color": "#FFFFFF"}, "showarrow": false, "text": "1", "x": "keyboard", "xref": "x", "y": "conversation", "yref": "y"}, {"font": {"color": "#FFFFFF"}, "showarrow": false, "text": "2", "x": "air conditioning", "xref": "x", "y": "conversation", "yref": "y"}, {"font": {"color": "#FFFFFF"}, "showarrow": false, "text": "3", "x": "conversation", "xref": "x", "y": "keyboard", "yref": "y"}, {"font": {"color": "#000000"}, "showarrow": false, "text": "383", "x": "keyboard", "xref": "x", "y": "keyboard", "yref": "y"}, {"font": {"color": "#FFFFFF"}, "showarrow": false, "text": "0", "x": "air conditioning", "xref": "x", "y": "keyboard", "yref": "y"}, {"font": {"color": "#FFFFFF"}, "showarrow": false, "text": "0", "x": "conversation", "xref": "x", "y": "air conditioning", "yref": "y"}, {"font": {"color": "#FFFFFF"}, "showarrow": false, "text": "0", "x": "keyboard", "xref": "x", "y": "air conditioning", "yref": "y"}, {"font": {"color": "#000000"}, "showarrow": false, "text": "387", "x": "air conditioning", "xref": "x", "y": "air conditioning", "yref": "y"}, {"font": {"color": "black", "size": 14}, "showarrow": false, "text": "Predicted value", "x": 0.5, "xref": "paper", "y": -0.15, "yref": "paper"}, {"font": {"color": "black", "size": 14}, "showarrow": false, "text": "Real value", "textangle": -90, "x": -0.35, "xref": "paper", "y": 0.5, "yref": "paper"}], "margin": {"l": 200, "t": 50}, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type" ...
